# %%
import numpy as np

# %% [markdown]
# ### Third section practice
# To this section i want to make two mini project to linear weigthed combination, dot product.

# %% [markdown]
# ### First Project
# Create a linear weigthed combination of three vectors. You'll learn in later chapter that linear-combination are most efficiently repressented as matrix-vector multiplaction, but we'll keep things simple for now. create three 5-D vectors and a fourth vector that contains the weigths for each vector. then create the weigthed sum of those vectors. Next, modify the code to compute the weigthed mixture of four 5-D vector What is the relationship between the dimenctionality of the to bo-summed, the number of vectors to sum, and the dimenctionality of the coefficient vector?

# %%
### Soulation 
V1 = np.array([2,3,4,5,6])
V2 = np.array([1,2,3,4,5])
V3 = np.array([9,8,8,4,2])
W = [8,-2,9]
Result = V1[0] + V2[1] + V3[2]
print(f"Result of our linear weigthed {Result}")
# Out:
# Result of our linear weigthed 12

# %% [markdown]
# ### Secound project
# * Alghorithm of our project
# * Develop a method to use the dot product to compute the average of a set of numbers in a vectors. (Hint: consider the vector of all ones, sometimes written 1.)

# %%
### Soulation
sets = [2,3,4,5,8]
o = np.ones(len(sets))
ave = np.dot(sets,o)/len(sets)
print(f"The result  of average: {ave}")
# Out:
# The result  of average: 4.4
